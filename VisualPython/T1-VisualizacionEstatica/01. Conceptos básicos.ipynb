# %% [markdown]
# ![MatPlotLib](https://matplotlib.org/_static/logo_light.svg)

# %% [markdown]
# Importación de librerías:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Un gráfico básico:

# %%
fig, ax = plt.subplots()             
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  
plt.show()

# %% [markdown]
# Anatomía de una figura:
#
# <img width=600 src="https://matplotlib.org/stable/_images/anatomy.png">
#
# *Fuente: https://matplotlib.org/stable/_images/anatomy.png*

# %% [markdown]
# ¿Cómo podemos crear figuras?

# %%
fig = plt.figure()

# %%
fig, ax = plt.subplots()

# %%
fig, axs = plt.subplots(2, 2)

# %%
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])
