# %% [markdown]
# <a href="https://colab.research.google.com/github/dgmx/Colab/blob/main/CDYPC01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importamos la libreria Pandas

# %%
import pandas as pd

# %% [markdown]
# Creamos una variable llamada df1 donde almacenamos los datos del archivo `lista_personas.csv`

# %%
df1 = pd.read_csv("lista_personas.csv")

# %% [markdown]
# Mostramos los datos almacenados en `df1`

# %%
df1
# Out:
#        Nombre  Edad  Altura
# 0     Antonio    18    1.75
# 1      Yanira    19    1.65
# 2      Carlos    20    1.83
# 3       Lucia    18    1.72
# 4      Miguel    19    1.73
# 5     Carmen     20    1.83
# 6   Mari Luz     21    1.67
# 7  Adoración     22    1.76
# 8   Francisco    23    1.80

# %%
df1.plot.bar(x="Nombre", y="Altura", color="green")
# Out:
# <Axes: xlabel='Nombre'>

# %%
df1['Altura'].mean()
# Out:
# np.float64(1.748888888888889)

# %%
df1['Edad'].value_counts()
# Out:
# Edad
# 18    2
# 19    2
# 20    2
# 21    1
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#     Nombre  Edad  Altura
# 0  Antonio    18    1.75
# 1   Yanira    19    1.65
# 2   Carlos    20    1.83
# 3    Lucia    18    1.72
# 4   Miguel    19    1.73

# %%
df1.sort_values("Altura", inplace=True, ascending=False)

# %%
df1
# Out:
#        Nombre  Edad  Altura
# 2      Carlos    20    1.83
# 5     Carmen     20    1.83
# 8   Francisco    23    1.80
# 7  Adoración     22    1.76
# 0     Antonio    18    1.75
# 4      Miguel    19    1.73
# 3       Lucia    18    1.72
# 6   Mari Luz     21    1.67
# 1      Yanira    19    1.65

# %%
df1.sort_index()
# Out:
#        Nombre  Edad  Altura
# 0     Antonio    18    1.75
# 1      Yanira    19    1.65
# 2      Carlos    20    1.83
# 3       Lucia    18    1.72
# 4      Miguel    19    1.73
# 5     Carmen     20    1.83
# 6   Mari Luz     21    1.67
# 7  Adoración     22    1.76
# 8   Francisco    23    1.80

# %%
df1[(df1['Edad']>=19) & (df1[ 'Altura']>1.70)]
# Out:
#        Nombre  Edad  Altura
# 2      Carlos    20    1.83
# 5     Carmen     20    1.83
# 8   Francisco    23    1.80
# 7  Adoración     22    1.76
# 4      Miguel    19    1.73
